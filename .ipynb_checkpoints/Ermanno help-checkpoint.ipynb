# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/francesco/Downloads/Popular_Baby_Names.csv')

# %%
df.shape
# Out:
# (19418, 6)

# %%
df.head(10)
# Out:
#    Year of Birth  Gender                   Ethnicity Child's First Name  \
# 0           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Olivia
# 1           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Chloe
# 2           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Sophia
# 3           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Emily
# 4           2016  FEMALE  ASIAN AND PACIFIC ISLANDER               Emma
# 5           2016  FEMALE  ASIAN AND PACIFIC ISLANDER                Mia
# 6           2016  FEMALE  ASIAN AND PACIFIC ISLANDER          Charlotte
# 7           2016  FEMALE  ASIAN AND PACIFIC ISLANDER              Sarah
# 8           2016  FEMALE  ASIAN AND PACIFIC ISLANDER           Isabella
# 9           2016  FEMALE  ASIAN AND PACIFIC ISLANDER             Hannah
#
#    Count  Rank
# 0    172     1
# 1    112     2
# 2    104     3
# 3     99     4
# 4     99     4
# 5     79     5
# 6     59     6
# 7     57     7
# 8     56     8
# 9     56     8

# %%
df.dtypes
# Out:
# Year of Birth          int64
# Gender                object
# Ethnicity             object
# Child's First Name    object
# Count                  int64
# Rank                   int64
# dtype: object

# %%
df.describe()
# Out:
#        Year of Birth         Count          Rank
# count   19418.000000  19418.000000  19418.000000
# mean     2013.124318     33.520084     57.497116
# std         1.599749     38.243201     25.363693
# min      2011.000000     10.000000      1.000000
# 25%      2012.000000     13.000000     38.000000
# 50%      2013.000000     20.000000     59.000000
# 75%      2014.000000     36.000000     78.000000
# max      2016.000000    426.000000    102.000000

# %%
df2 = df.rename(columns = {'Year of Birth':'YearOfBirth', 'Child\'s First Name':'ChildsFirstName'})


#Could also do like this below: inplace=True lets you set it to the current dataframe
# df.rename(columns = {'Year of Birth':'YearOfBirth', 'Child\'s First Name':'ChildsFirstName'}, inplace=True)

# %%
#df.head() automatically shows the first 5 rows instead of printing the whole dataframe. 
#(df.head(10) will show the first 10 rows)
df2.head()
# Out:
#    YearOfBirth  Gender                   Ethnicity ChildsFirstName  Count  \
# 0         2016  FEMALE  ASIAN AND PACIFIC ISLANDER          Olivia    172
# 1         2016  FEMALE  ASIAN AND PACIFIC ISLANDER           Chloe    112
# 2         2016  FEMALE  ASIAN AND PACIFIC ISLANDER          Sophia    104
# 3         2016  FEMALE  ASIAN AND PACIFIC ISLANDER           Emily     99
# 4         2016  FEMALE  ASIAN AND PACIFIC ISLANDER            Emma     99
#
#    Rank
# 0     1
# 1     2
# 2     3
# 3     4
# 4     4

# %%
#Drop duplicates inplace=True to change the dataframe
df2.drop_duplicates(inplace=True)
df2.shape
# Out:
# (12181, 6)

# %%
#Select the column of interest: df.ChildsFirstName use .unique() to find the unique values and len will give you the number
len(df2.ChildsFirstName.unique())
# Out:
# 3021

# %%
'''
by is which columns you want to sort by. 
A column is written as either df['Rank'] or df.Rank

Muliple columns can be written in the same set of square brackets.
The order of columns is important depending on how you want to sort them. ['Rank', 'Gender'] != ['Gender', 'Rank'] try it

[0:60] prints the first 60 rows 
'''
df2.sort_values(by=['Rank', 'YearOfBirth', 'Gender', 'Ethnicity'])[0:60]
# Out:
# 15520         2011  FEMALE  ASIAN AND PACIFIC ISLANDER           CHLOE    106
# 15830         2011  FEMALE          BLACK NON HISPANIC          LONDON     92
# 16195         2011  FEMALE                    HISPANIC             MIA    229
# 16840         2011  FEMALE          WHITE NON HISPANIC          OLIVIA    213
# 16841         2011  FEMALE          WHITE NON HISPANIC            EMMA    213
# 17517         2011    MALE  ASIAN AND PACIFIC ISLANDER          JAYDEN    173
# 17819         2011    MALE          BLACK NON HISPANIC           AIDEN    167
# 18215         2011    MALE                    HISPANIC          JUSTIN    310
# 18799         2011    MALE          WHITE NON HISPANIC          JOSEPH    281
# 11665         2012  FEMALE              ASIAN AND PACI          SOPHIA    144
# 12014         2012  FEMALE              BLACK NON HISP          LONDON     87
#
#        Rank
# 15518     1
# 15828     1
# 16193     1
# 16838     1
# 17515     1
# 17817     1
# 18214     1
# 18797     1
# 11663     1
# 12013     1
# 12343     1
# 12928     1
# 13640     1
# 13983     1
# 14334     1
# 14892     1
# 7898      1
# 8225      1
# 8560      1
# 9120      1
# 9808      1
# 10127     1
# 10472     1
# 11020     1
# 4108      1
# 4445      1
# 4788      1
# 5342      1
# 6066      1
# 6413      1
# 6743      1
# 7260      1
# 2063      1
# 2250      1
# 2433      1
# 2721      1
# 2722      1
# 3107      1
# 3294      1
# 3477      1
# 3762      1
# 0         1
# 182       1
# 356       1
# 661       1
# 1047      1
# 1242      1
# 1413      1
# 1699      1
# 15520     2
# 15830     2
# 16195     2
# 16840     2
# 16841     2
# 17517     2
# 17819     2
# 18215     2
# 18799     2
# 11665     2
# 12014     2

# %%
'''
groupby is kind of like .unique() it groups the data based on name.
you then want to sort that data based on the sum of Count 
you then want to sort_values that data ascending = False so the highest counts appear at the top
then print the top 10 names

(try printing it out bit by bit to see what its doing)
'''
df2.groupby(['ChildsFirstName'])['Count'].sum().sort_values(ascending=False)[0:10]
# Out:
# ChildsFirstName
# Ethan      2852
# Jacob      2654
# Liam       2513
# Noah       2424
# Jayden     2380
# Sophia     2278
# Daniel     2242
# Olivia     2178
# Matthew    2137
# David      2119
# Name: Count, dtype: int64

# %%
'''
Use the groupby we did above as a new dataframe (most_common_names)
Then groupby gender and take the largest 10 values of each gender
'''
most_common_names = df2.groupby(['ChildsFirstName', 'Gender'])['Count'].sum().sort_values(ascending=False)
most_common_names.groupby('Gender').nlargest(10)
# Out:
# Gender  ChildsFirstName  Gender
# FEMALE  Sophia           FEMALE    2278
#         Olivia           FEMALE    2178
#         Isabella         FEMALE    2093
#         Emma             FEMALE    2038
#         Mia              FEMALE    1954
#         Emily            FEMALE    1646
#         Leah             FEMALE    1483
#         Ava              FEMALE    1459
#         Madison          FEMALE    1324
#         Sofia            FEMALE    1324
# MALE    Ethan            MALE      2852
#         Jacob            MALE      2654
#         Liam             MALE      2513
#         Noah             MALE      2424
#         Jayden           MALE      2380
#         Daniel           MALE      2242
#         Matthew          MALE      2137
#         David            MALE      2119
#         Michael          MALE      2098
#         Aiden            MALE      2044
# Name: Count, dtype: int64

# %%
'''
Groupby the name and then count the sum as above
Only select the values less or equal to 10
sum them to find the total number
'''
(df2.groupby(['ChildsFirstName'])['Count'].sum().sort_values(ascending=False) <= 10).sum()
# Out:
# 223

# %%
'''
Go do one you mug
8==D
'''
